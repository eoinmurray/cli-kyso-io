# %% [markdown]
# # Do you win by scoring or defending?
#
# In this post I'm going to try an figure out the answer to the following question:
#
# > For teams that win the most games, do they win by scoring more, or giving away less goals?
#
# To do this we will look at the data for the 2016/2017 Champions League. Luckily all the
# data is available on the awesome [football-data.org](http://api.football-data.org/) api!

# %%
# %pylab inline
import requests
import pandas
from bokeh.charts import Bar
from bokeh.io import output_notebook, show
from bokeh.layouts import layout, gridplot
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource

output_notebook()

api_key = 'f4466371787c4fd89d1c0f7f56c0728f'
headers = { 'X-Auth-Token': api_key }

champ_leq = requests.get('http://api.football-data.org/v1/competitions/440', headers=headers).json()
fixtures = requests.get(champ_leq['_links']['fixtures']['href'], headers=headers).json()
leagueTable = requests.get(champ_leq['_links']['leagueTable']['href'], headers=headers).json()
# Out:
# Populating the interactive namespace from numpy and matplotlib
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e16b3206-2a1f-445c-aaff-368108b579e5">Loading BokehJS ...</span>
#     </div>

# %%
def remix(data): 
    o = {}
    o['awayTeam'] = data['awayTeamName']
    o['homeTeam'] = data['homeTeamName']
    
    o['homeTeamGoals'] = data['result']['goalsHomeTeam']    
    o['awayTeamGoals'] = data['result']['goalsAwayTeam']
    
    o['winner'] = None
    o['loser'] = None
    o['winnerGoals']= 0
    o['loserGoals']= 0
    
    if data['status'] == 'FINISHED' or data['status'] == 'FT':
        if o['homeTeamGoals'] > o['awayTeamGoals']:
            o['winner'] = o['homeTeam']
            o['winnerGoals'] = o['homeTeamGoals']
            o['loser'] = o['awayTeam']
            o['loserGoals'] = o['homeTeamGoals']

        if o['awayTeamGoals'] > o['homeTeamGoals']:
            o['winner'] = o['awayTeam']
            o['winnerGoals'] = o['awayTeamGoals']
            o['loser'] = o['homeTeam']
            o['loserGoals'] = o['homeTeamGoals']
    
    o['goalDelta'] = o['winnerGoals'] - o['loserGoals']
    
    return o

games = [remix(d) for d in fixtures['fixtures']]

# %% [markdown]
# # Number of wins per team

# %%
group = pandas.DataFrame(games)[['winner']]
p = Bar(group.apply(pandas.value_counts), legend=False)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="faf4341e-276c-4489-968f-413906a6b7a9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("faf4341e-276c-4489-968f-413906a6b7a9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("faf4341e-276c-4489-968f-413906a6b7a9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'faf4341e-276c-4489-968f-413906a6b7a9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3cfae70a-ab20-4d49-9ab3-b15ad8b5b269":{"roots":{"references":[{"attributes":{"data_source":{"id":"c7a98ced-6078-422e-95f7-2f2dd8fdd3db","type":"ColumnDataSource"},"glyph":{"id":"2e1d7158-ce4a-493f-b1ff-10cae8e9004c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"b9efb8eb-8163-4794-98e0-498de34302ac","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1dd9de81-99fc-4d38-8f6a-bed355f1ee97","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","line_alpha","width","fill_alpha","color","line_color","label","height","y"],"data":{"chart_index":[{"index":"Borussia Dortmund"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[5.0],"index":["Borussia Dortmund"],"label":[{"index":"Borussia Dortmund"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Borussia Dortmund"],"y":[2.5]}},"id":"e872aa90-0325-40f2-89e9-1707a376677e","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7aac96aa-0c1d-4aff-81ee-37bad63cfedb","type":"Rect"},{"attributes":{"data_source":{"id":"5eda8784-f11a-4d89-a234-eb9c1ed2a03b","type":"ColumnDataSource"},"glyph":{"id":"7d579136-a94c-437a-bcfc-8ddaea12da1c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f939676a-7b83-4f00-9fc3-d15876042698","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f3045ea1-9e76-47e1-8969-f0e47e04ca89","type":"Rect"},{"attributes":{"data_source":{"id":"da2088c2-6df8-4e44-aeca-ab7ec001b0ea","type":"ColumnDataSource"},"glyph":{"id":"f3045ea1-9e76-47e1-8969-f0e47e04ca89","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a02ad0fb-ed53-4240-90c4-08906bd1d490","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["AS Monaco FC","Arsenal FC","Bayer Leverkusen","Besiktas JK","Bor. M\u00f6nchengladbach","Borussia Dortmund","Club Atl\u00e9tico de Madrid","Dynamo Kyiv","FC Barcelona","FC Bayern M\u00fcnchen","FC Copenhagen","FC Porto","FC Rostov","Juventus Turin","Legia Warszawa","Leicester City FC","Manchester City FC","Olympique Lyonnais","Paris Saint-Germain","Real Madrid CF","SL Benfica","SSC Napoli","Sevilla FC","Sporting CP","Tottenham Hotspur FC"]},"id":"ac4d81e9-c139-40cd-9a13-40b2a277a856","type":"FactorRange"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a036955d-bf48-4e4c-a0b2-91ca8161d10f","type":"Rect"},{"attributes":{"data_source":{"id":"831856b1-0965-4998-b4d5-337987ddee5d","type":"ColumnDataSource"},"glyph":{"id":"424a0ef6-ac47-4454-8376-274f1103f147","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a79d525f-9458-4315-904d-ecbcb18ecfea","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"fbe7f5a1-316a-490e-aa41-359170f79702","type":"ColumnDataSource"},"glyph":{"id":"6558cec4-9447-4225-9db2-9062c4dff9e8","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"0ad79568-b8dd-4c3b-acfb-b36876c30602","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"17035e14-23fa-46be-899a-5b4a4e945d5b","type":"ColumnDataSource"},"glyph":{"id":"7aac96aa-0c1d-4aff-81ee-37bad63cfedb","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"25520bca ...

# %% [markdown]
# # Number of goals per away team

# %%
p1 = Bar(pandas.DataFrame(games)[['awayTeam', 'awayTeamGoals']].groupby('awayTeam').sum(), legend=False, title="Away Goals Scored")
p2 = Bar(pandas.DataFrame(games)[['awayTeam', 'homeTeamGoals']].groupby('awayTeam').sum(), legend=False, title="Away Goals Conceded")

l = layout([
  [p1, p2]
], sizing_mode='scale_width')

show(l)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b530d440-e263-49d0-96c5-1287d9be653f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b530d440-e263-49d0-96c5-1287d9be653f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b530d440-e263-49d0-96c5-1287d9be653f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b530d440-e263-49d0-96c5-1287d9be653f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d8169243-3b3e-4fab-9491-cb4e8b4632c8":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9ddafce8-283a-4398-902e-e6e67fa2f3de","type":"Rect"},{"attributes":{"data_source":{"id":"59583a83-e843-4b8c-867a-f299acdaa996","type":"ColumnDataSource"},"glyph":{"id":"54795a0c-344f-48c0-9e5c-9a10fbb8536d","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"7f9fb2b2-bd30-45f2-a082-e262c30234bd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3feae41a-f1ad-4da6-a0ee-232da5f9213a","type":"ColumnDataSource"},"glyph":{"id":"66179563-2d22-40ea-8725-14855ac806ce","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"d5b346dc-bc77-482e-87e8-441dff15d224","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"48a19d12-3937-4a43-8676-39c5e36e14e2","type":"ColumnDataSource"},"glyph":{"id":"b9c32b8b-1e72-4a84-829d-9710bb997e7d","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"df348728-cad9-4a26-9640-293ae8b8d282","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e9f9af48-2d8a-4c6e-b0e5-8ca97952181c","type":"PanTool"},{"id":"03c595d5-53f9-41e8-9b92-e17730f0fb2a","type":"WheelZoomTool"},{"id":"2c0705d1-3824-41c0-a6a2-5bae6b13e994","type":"BoxZoomTool"},{"id":"95c19522-d76d-4a4d-ae27-62bdc04fd9ac","type":"SaveTool"},{"id":"ddf9534d-be70-4aed-8831-814da0af3a59","type":"ResetTool"},{"id":"69b3520d-e48c-4518-9a54-a136e0fbca0b","type":"HelpTool"}]},"id":"e0fc3c5c-c6e7-4861-841d-2745c1d1bc61","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","line_alpha","width","fill_alpha","color","line_color","label","height","y"],"data":{"chart_index":[{"index":"Besiktas JK"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[9.0],"index":["Besiktas JK"],"label":[{"index":"Besiktas JK"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Besiktas JK"],"y":[4.5]}},"id":"010c7127-c847-408e-90c2-032a4042af57","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"012d4308-6d04-48bb-8b62-ed807672cf5f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d084ffb1-62b4-4751-8134-208ea2320788","type":"Rect"},{"attributes":{"data_source":{"id":"84c3f785-3ca5-4520-a780-d2b238223f79","type":"ColumnDataSource"},"glyph":{"id":"b4256558-7b59-43e9-b09b-0f116e0bc1f1","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"ceef100f-0637-48fa-ba1c-0e0326db57fb","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9c8c7939-8d6e-48ae-90a7-40f68f556997","type":"Rect"},{"attributes":{"overlay":{"id":"11258b81-7670-49ac-a12a-e87aade678d3","type":"BoxAnnotation"},"plot":{"id":"f863844b-812c-4271-b46f-5f0c9c29f287","subtype":"Chart","type":"Plot"}},"id":"2c0705d1-3824-41c0-a6a2-5bae6b13e994","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","line_alpha","width","fill_alpha","color","line_color","label","height","y"],"data":{"chart_index":[{"index":"AS Monaco FC"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[12.0],"index":["AS Monaco FC"],"label":[{"index":"AS Monaco FC"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["AS Monaco FC"],"y":[6 ...

# %% [markdown]
# # Number of goals per home team

# %%
p1 = Bar(pandas.DataFrame(games)[['homeTeam', 'homeTeamGoals']].groupby('homeTeam').sum(), legend=False, title="Home Goals Scored")
p2 = Bar(pandas.DataFrame(games)[['homeTeam', 'awayTeamGoals']].groupby('homeTeam').sum(), legend=False, title="Home Goals Conceded")

l = layout([
  [p1, p2]
], sizing_mode='scale_width')

show(l)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ad6eb679-410e-44d8-9b3a-c158f15f2b9d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ad6eb679-410e-44d8-9b3a-c158f15f2b9d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ad6eb679-410e-44d8-9b3a-c158f15f2b9d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ad6eb679-410e-44d8-9b3a-c158f15f2b9d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bb4d05f0-c5db-4c91-8d81-6f9b109fdb8d":{"roots":{"references":[{"attributes":{},"id":"3ad43ea6-a819-4efd-a801-558fba2f86f0","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"81c73fbd-8505-4ce8-8357-1d0e3be3632c","type":"ColumnDataSource"},"glyph":{"id":"2ddbaa55-e53b-44a3-957d-11296351a6cc","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e2adcfee-0d8b-4b76-8ece-e0f28dd7c308","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","line_alpha","width","fill_alpha","color","line_color","label","height","y"],"data":{"chart_index":[{"index":"FC Bayern M\u00fcnchen"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"index":["FC Bayern M\u00fcnchen"],"label":[{"index":"FC Bayern M\u00fcnchen"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["FC Bayern M\u00fcnchen"],"y":[2.0]}},"id":"4b9527ad-c46a-4643-81f8-9052914c332c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c218d345-84df-429d-9a13-27879f60797f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4613c8b7-d582-4d2c-b478-36669d388832","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"65a7c09e-3ea4-4ff0-a0c8-16bd89b13a33","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5ea56e84-6955-4622-8e9c-d81d45c69cab","type":"Rect"},{"attributes":{"plot":{"id":"320b9f01-81ce-4751-9042-4823cf8b1969","subtype":"Chart","type":"Plot"}},"id":"faf02d3c-e671-44a8-b37b-fe8e3adcf27f","type":"HelpTool"},{"attributes":{"data_source":{"id":"4debb889-d2ce-4b73-81c5-fba18b52c508","type":"ColumnDataSource"},"glyph":{"id":"c218d345-84df-429d-9a13-27879f60797f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"65acc36c-52ad-43f1-be87-713f8170a7dc","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e5c6d9df-44e5-4404-abd6-0b28feeb3e04","type":"ColumnDataSource"},"glyph":{"id":"9e1557ba-479e-437d-9cc6-e729fb8b0837","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e46617da-c2d8-48e7-bc77-a5ea13c042f3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","line_alpha","width","fill_alpha","color","line_color","label","height","y"],"data":{"chart_index":[{"index":"AS Monaco FC"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[12.0],"index":["AS Monaco FC"],"label":[{"index":"AS Monaco FC"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["AS Monaco FC"],"y":[6.0]}},"id":"3ca08b0c-90bf-4dad-a5e3-4e7c0a25814f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c2516df1-eea2-47c4-9b02-f4c493819d47","type":"ColumnDataSource"},"glyph":{"id":"8e48034b-83ab-40d5-9b0f-606a659945a8","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"eec7e0ff-b405-445c-bf1e-6621c37c55a3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","line_alpha","width","fill_alpha","color","line_color","label","height","y"],"data":{"chart_index":[{"index":"Legia Warszawa"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"index":["Legia Warszawa"],"label":[{"index":"Legia Warszawa"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Legia Warszawa"],"y":[2.0]}},"id":"866358b6-0f3e-44fe-88 ...

# %% [markdown]
# # Total number of goals per team

# %%
df_away = pandas.DataFrame(games)[['awayTeam', 'awayTeamGoals', 'homeTeamGoals']].groupby('awayTeam').sum()
df_home = pandas.DataFrame(games)[['homeTeam', 'homeTeamGoals', 'homeTeamGoals']].groupby('homeTeam').sum()
df_away.index.names = ['Team']
df_home.index.names = ['Team']
df_away.columns = ['scored', 'conceded']
df_home.columns = ['scored', 'conceded']

df_total = df_home + df_away

# %%
source = ColumnDataSource(data=df_total)

p1 = figure(source=source, legend=False, title="Scored")
p1 = Bar(df_total['conceded'], legend=False, title="Conceded")


# g = gridplot([[p1, p2]], toolbar_location=None, sizing_mode='scale_width')
# show(g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-7d6d25f5470c> in <module>()
#       1 source = ColumnDataSource(data=df_total)
#       2
# ----> 3 p1 = figure(source=source, legend=False, title="Scored")
#       4 p1 = Bar(df_total['conceded'], legend=False, title="Conceded")
#       5
#
# /usr/local/lib/python3.5/dist-packages/bokeh/plotting/figure.py in figure(**kwargs)
#     650     '''
#     651
# --> 652     return Figure(**kwargs)
#     653
#     654
#
# /usr/local/lib/python3.5/dist-packages/bokeh/plotting/figure.py in __init__(self, *arg, **kw)
#     114             kw['title'] = Title(text=title)
#     115
# --> 116         super(Figure, self).__init__(*arg, **kw)
#     117
#     118         self.x_range = _get_range(opts.x_range)
#
# /usr/local/lib/python3.5/dist-packages/bokeh/models/plots.py in __init__(self, **kwargs)
#      48             kwargs["toolbar"] = Toolbar(tools=tools, logo=logo)
#      49
# ---> 50         super(LayoutDOM, self).__init__(**kwargs)
#      51
#      52     def select(self, *args, **kwargs):
#
# /usr/local/lib/python3.5/dist-packages/bokeh/model.py in __init__(self, **kwargs)
#     224         self._id = kwargs.pop("id", make_id())
#     225         self._document = None
# --> 226         super(Model, self).__init__(**kwargs)
#     227         default_theme.apply_to_model(self)
#     228
#
# /usr/local/lib/python3.5/dist-packages/bokeh/core/has_props.py in __init__(self, **properties)
#     239
#     240         for name, value in properties.items():
# --> 241             setattr(self, name, value)
#     242
#     243     def __setattr__(self, name, value):
#
# /usr/local/lib/python3.5/dist-packages/bokeh/core/has_props.py in __setattr__(self, name, value)
#     275
#     276             raise AttributeError("unexpected attribute '%s' to %s, %s attributes are %s" %
# --> 277                 (name, self.__class__.__name__, text, nice_join(matches)))
#     278
#     279     def __str__(self):
#
# AttributeError: unexpected attribute 'source' to Figure, possible attributes are above, background_fill_alpha, background_fill_color, below, border_fill_alpha, border_fill_color, css_classes, disabled, extra_x_ranges, extra_y_ranges, h_symmetry, height, hidpi, inner_height, inner_width, js_event_callbacks, js_property_callbacks, layout_height, layout_width, left, lod_factor, lod_interval, lod_threshold, lod_timeout, min_border, min_border_bottom, min_border_left, min_border_right, min_border_top, name, outline_line_alpha, outline_line_cap, outline_line_color, outline_line_dash, outline_line_dash_offset, outline_line_join, outline_line_width, plot_height, plot_width, renderers, right, sizing_mode, subscribed_events, tags, title, title_location, tool_events, toolbar, toolbar_location, toolbar_sticky, v_symmetry, webgl, width, x_mapper_type, x_range, y_mapper_type or y_range
