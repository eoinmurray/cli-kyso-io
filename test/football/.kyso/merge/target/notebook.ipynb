# %% [markdown]
# # Do you win by scoring or defending?
#
# In this post I'm going to try an figure out the answer to the following question:
#
# > For teams that win the most games, do they win by scoring more, or giving away less goals?
#
# To do this we will look at the data for the 2016/2017 Champions League. Luckily all the
# data is available on the awesome [football-data.org](http://api.football-data.org/) api!

# %%
# %pylab inline
import requests
import pandas
from bokeh.charts import Bar
from bokeh.io import output_notebook, show
from bokeh.layouts import layout, gridplot
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource


output_notebook()

api_key = 'f4466371787c4fd89d1c0f7f56c0728f'
headers = { 'X-Auth-Token': api_key }

champ_leq = requests.get('http://api.football-data.org/v1/competitions/440', headers=headers).json()
fixtures = requests.get(champ_leq['_links']['fixtures']['href'], headers=headers).json()
leagueTable = requests.get(champ_leq['_links']['leagueTable']['href'], headers=headers).json()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.5/dist-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['figure', 'show']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e9e1cc1c-e736-4624-82e5-2bf8907de201">Loading BokehJS ...</span>
#     </div>

# %%
def remix(data): 
    o = {}
    o['awayTeam'] = data['awayTeamName']
    o['homeTeam'] = data['homeTeamName']
    
    o['homeTeamGoals'] = data['result']['goalsHomeTeam']    
    o['awayTeamGoals'] = data['result']['goalsAwayTeam']
    
    o['winner'] = None
    o['loser'] = None
    o['winnerGoals']= 0
    o['loserGoals']= 0
    
    if data['status'] == 'FINISHED' or data['status'] == 'FT':
        if o['homeTeamGoals'] > o['awayTeamGoals']:
            o['winner'] = o['homeTeam']
            o['winnerGoals'] = o['homeTeamGoals']
            o['loser'] = o['awayTeam']
            o['loserGoals'] = o['homeTeamGoals']

        if o['awayTeamGoals'] > o['homeTeamGoals']:
            o['winner'] = o['awayTeam']
            o['winnerGoals'] = o['awayTeamGoals']
            o['loser'] = o['homeTeam']
            o['loserGoals'] = o['homeTeamGoals']
    
    o['goalDelta'] = o['winnerGoals'] - o['loserGoals']
    
    return o

games = [remix(d) for d in fixtures['fixtures']]

# %% [markdown]
# # Number of wins per team

# %%
group = pandas.DataFrame(games)[['winner']]
p = Bar(group.apply(pandas.value_counts), legend=False)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="80835ff6-568c-4156-9f5b-d0e2a3056130"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("80835ff6-568c-4156-9f5b-d0e2a3056130");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("80835ff6-568c-4156-9f5b-d0e2a3056130");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '80835ff6-568c-4156-9f5b-d0e2a3056130' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"454d7715-7851-439c-b0c9-d98ef0048c47":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_alpha","label","fill_alpha","x","line_color","width","y","height","color"],"data":{"chart_index":[{"index":"Sporting CP"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"index":["Sporting CP"],"label":[{"index":"Sporting CP"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Sporting CP"],"y":[0.5]}},"id":"b65849b2-a18a-4119-b60c-dbab81313fc7","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"08652f9f-efc3-46c9-8644-f2140558616b","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"57d4f8c1-534a-4100-b668-ce649f59102c","type":"Rect"},{"attributes":{},"id":"499d5e63-9425-4823-b5bd-17a6fa0e4b7c","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"caa26363-31cc-460d-b815-667cdd45ad4d","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5553ef9f-6cd2-4245-a14f-fe441e5e5e4b","type":"Rect"},{"attributes":{"overlay":{"id":"f32af8ca-f30f-465a-8a2b-019f047f8cd1","type":"BoxAnnotation"},"plot":{"id":"db97a2c5-8d00-4d7f-9a53-bfdd3b8787db","subtype":"Chart","type":"Plot"}},"id":"a437bc02-9787-48c6-8337-38089dc8f359","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"d629eed2-ee31-4d14-b5ea-22b40eba0fab","type":"ColumnDataSource"},"glyph":{"id":"08652f9f-efc3-46c9-8644-f2140558616b","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"0f57d4fb-eb68-4bad-8893-3d773efd787b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c19219d3-a736-4388-9b73-f88573e5e28a","type":"ColumnDataSource"},"glyph":{"id":"7381a096-dd30-426b-87d9-340d35d90ec8","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"1f61798b-6ccc-4c1d-bdb9-8af99b3e107a","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"57d868f7-0fd1-42c7-bce7-3558f14d5ad8","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2dbc7f55-e78d-485e-8de3-dd8480cd50b4","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6615635d-e3e3-4788-a054-e45689090e53","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"05847294-6253-49d7-9563-355de92b3757","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_alpha","label","fill_alpha","x","line_color","width","y","height","color"],"data":{"chart_index":[{"index":"FC Barcelona"}],"color ...

# %% [markdown]
# # Number of goals per away team

# %%
p1 = Bar(pandas.DataFrame(games)[['awayTeam', 'awayTeamGoals']].groupby('awayTeam').sum(), legend=False, title="Away Goals Scored")
p2 = Bar(pandas.DataFrame(games)[['awayTeam', 'homeTeamGoals']].groupby('awayTeam').sum(), legend=False, title="Away Goals Conceded")

l = layout([
  [p1, p2]
], sizing_mode='scale_width')

show(l)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f3451e18-69c8-46c5-9435-d5970345a5c5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f3451e18-69c8-46c5-9435-d5970345a5c5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f3451e18-69c8-46c5-9435-d5970345a5c5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f3451e18-69c8-46c5-9435-d5970345a5c5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6ff6f3e1-7e9b-4c73-8af5-adedc1fbb0cb":{"roots":{"references":[{"attributes":{"data_source":{"id":"45384563-1dea-4157-83ee-8e4470d21c0c","type":"ColumnDataSource"},"glyph":{"id":"2c980f6f-d364-430b-9575-0d098e994b04","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"6391e905-2220-4c96-bcdc-7491a306d935","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"92735bce-f09c-4958-8d3d-8a1b18fb8c8e","type":"PanTool"},{"id":"884619a7-11fc-4e6e-a8b1-b6eb1ccd276d","type":"WheelZoomTool"},{"id":"6b2c7dd3-1727-419e-9a3c-274ff3b673b3","type":"BoxZoomTool"},{"id":"ffc6bb20-992a-401c-afcc-ef6d230ff495","type":"SaveTool"},{"id":"cfe7268a-dd13-4219-9844-3be55a0d3f0b","type":"ResetTool"},{"id":"5ba768c9-348c-4a25-8d01-77c71bfa40b9","type":"HelpTool"}]},"id":"787328a5-d847-4a79-a42c-fd3696ddd6b1","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["line_alpha","label","fill_alpha","x","line_color","width","y","height","color"],"data":{"chart_index":[{"index":"Bor. M\u00f6nchengladbach"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"index":["Bor. M\u00f6nchengladbach"],"label":[{"index":"Bor. M\u00f6nchengladbach"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Bor. M\u00f6nchengladbach"],"y":[1.0]}},"id":"9ff8a957-3362-419b-a7e1-8a96cd3cefd4","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_alpha","label","fill_alpha","x","line_color","width","y","height","color"],"data":{"chart_index":[{"index":"Sporting CP"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"index":["Sporting CP"],"label":[{"index":"Sporting CP"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Sporting CP"],"y":[0.5]}},"id":"7d3df491-af25-42a9-9796-c0224762fda6","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b4235e70-03fd-4e77-bd37-8cfe31e4d742","type":"ColumnDataSource"},"glyph":{"id":"c07b7780-80cd-403f-9912-efcff139f49c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"87fad4da-e83e-4c14-9a89-1ecfa6c777db","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3fd6f189-6843-44ff-bd0c-80b01a96118c","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_alpha","label","fill_alpha","x","line_color","width","y","height","color"],"data":{"chart_index":[{"index":"Borussia Dortmund"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[7.0],"index":["Borussia Dortmund"],"label":[{"index":"Borussia Dortmund"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Borussia Dortmund"],"y":[3.5]}},"id":"95137ca9-b4a5-41eb-97b4-861b08c74938","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_alpha","label","fill_alpha","x","line_color","width","y","height","color"],"data":{"chart_index":[{"index":"CSKA Moscow"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"index":["CSKA Moscow"],"label":[{"index":"CSKA Moscow"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["CSKA Moscow"],"y":[1.5]}},"id":"0defce2f-b524-4cf9-93a0-c86f8419e9a4","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"19a6d954-d82e-4851-9ab0-16e23f78e337","type":"ColumnDataSource"},"glyph":{"id":"accd33c2-90de-4166-9b7c-cc696f6cd6ed","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"828db964-dc7f-4902-8bfd-ceec6cfa51e3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c07b7780-80cd-403f-9912-efcff139f49c","type":"Rect"},{"attributes":{"overlay":{"id":"4e7cffc7-29c4-4c14-95e9-b9250e1fc3d9","t ...

# %% [markdown]
# # Number of goals per home team

# %%
p1 = Bar(pandas.DataFrame(games)[['homeTeam', 'homeTeamGoals']].groupby('homeTeam').sum(), legend=False, title="Home Goals Scored")
p2 = Bar(pandas.DataFrame(games)[['homeTeam', 'awayTeamGoals']].groupby('homeTeam').sum(), legend=False, title="Home Goals Conceded")

l = layout([
  [p1, p2]
], sizing_mode='scale_width')

show(l)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5ed8c800-8b8e-4d96-af0b-c4d57e8a983f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5ed8c800-8b8e-4d96-af0b-c4d57e8a983f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5ed8c800-8b8e-4d96-af0b-c4d57e8a983f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5ed8c800-8b8e-4d96-af0b-c4d57e8a983f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6b200666-90b5-42f4-8604-2ba4451b5c4a":{"roots":{"references":[{"attributes":{"data_source":{"id":"bd7044a2-05af-4773-bb5b-21bdc8086e4e","type":"ColumnDataSource"},"glyph":{"id":"d1da257b-e648-4add-8441-b2b6cd198a7f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"50d85e89-19f9-4993-bdbf-1f76edf68a51","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_alpha","label","fill_alpha","x","line_color","width","y","height","color"],"data":{"chart_index":[{"index":"FC Copenhagen"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"index":["FC Copenhagen"],"label":[{"index":"FC Copenhagen"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["FC Copenhagen"],"y":[2.0]}},"id":"4a63ee2d-3216-45a3-971a-8d91138dd283","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":22.05},"id":"7953d63e-4e56-40b3-90f2-08362788b62b","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_alpha","label","fill_alpha","x","line_color","width","y","height","color"],"data":{"chart_index":[{"index":"Club Brugge"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"index":["Club Brugge"],"label":[{"index":"Club Brugge"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Club Brugge"],"y":[0.5]}},"id":"2b86e271-eec8-41fc-b5e0-cb1a40092bea","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_alpha","label","fill_alpha","x","line_color","width","y","height","color"],"data":{"chart_index":[{"index":"Tottenham Hotspur FC"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"index":["Tottenham Hotspur FC"],"label":[{"index":"Tottenham Hotspur FC"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Tottenham Hotspur FC"],"y":[2.0]}},"id":"5c2e086a-e50a-4e46-8d9a-ba6c83d24817","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"4c31cd0d-5999-48f3-9f94-4ca32a002f63","type":"ColumnDataSource"},"glyph":{"id":"e0654c46-f1ab-4591-ad1b-301659984d52","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"c5e54e09-7b2a-43b6-8b54-891387c97d70","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b2eabb9-521d-4e8b-ab0b-0b68078a56c6","type":"Rect"},{"attributes":{"plot":{"id":"e34ac866-19e0-4bc1-a899-c09597cdd078","subtype":"Chart","type":"Plot"}},"id":"fdfb3b06-59e6-4b3b-a8e6-f2f9c4b5760d","type":"ResetTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6d1e8655-74ff-4e84-8193-4b3077bc1b9f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3620742c-fc57-4372-87d1-8d4ee9ac7d8d","type":"Rect"},{"attributes":{},"id":"ac5b8316-f771-4376-9efc-f670402e74c0","type":"CategoricalTicker"},{"attributes":{"callback":null,"factors":["AS Monaco FC","Arsenal FC","Bayer Leverkusen","Besiktas JK","Bor. M\u00f6nchengladbach","Borussia Dortmund","CSKA Moscow","Celtic FC","Club Atl\u00e9tico de Madrid","Club Brugge","Dynamo Kyiv","FC Barcelona","FC Basel","FC Bayern M\u00fcnchen","FC Copenhagen","FC Porto","FC Rostov","GNK Dinamo Zagreb","Juventus Turin","Legia Warszawa","Leicester City FC","Ludogorez Rasgrad","Manchester City FC","Olympique Lyonnais","PSV Eindhoven","Paris Saint-Germain","Real Madrid CF","SL Benfica","SSC Napoli","Sevilla FC","Sporting CP","Tottenham Hotspur FC"]},"id":"7709814f-0568-47b9-a422-715ee2487464","type":"FactorRange"},{"attributes":{"plot":{"id":"e34ac866-19e0-4bc1-a899-c09 ...

# %% [markdown]
# # Total number of goals per team

# %%
df_away = pandas.DataFrame(games)[['awayTeam', 'awayTeamGoals', 'homeTeamGoals']].groupby('awayTeam').sum()
df_home = pandas.DataFrame(games)[['homeTeam', 'homeTeamGoals', 'homeTeamGoals']].groupby('homeTeam').sum()
df_away.index.names = ['Team']
df_home.index.names = ['Team']
df_away.columns = ['scored', 'conceded']
df_home.columns = ['scored', 'conceded']

df_total = df_home + df_away

# %%
p1 = Bar(df_total['scored'], legend=False, title="Scored")
p1 = Bar(df_total['conceded'], legend=False, title="Conceded")

g = gridplot([[p1, p2]], toolbar_location=None, sizing_mode='scale_width')

show(g)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="53176992-ea11-4bc4-b0bc-9a7aab0f998c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("53176992-ea11-4bc4-b0bc-9a7aab0f998c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("53176992-ea11-4bc4-b0bc-9a7aab0f998c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '53176992-ea11-4bc4-b0bc-9a7aab0f998c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a0da8325-252d-451d-96ed-9c4865d77c84":{"roots":{"references":[{"attributes":{"below":[{"id":"111b43a4-fa52-437a-8bcb-77aa3375f423","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"dc4de683-18ee-4e73-ae4d-33fe5c474877","type":"LinearAxis"}],"renderers":[{"id":"8e100cac-cae2-4171-8f18-f3e4af593d4c","type":"BoxAnnotation"},{"id":"954de196-9a1b-417a-9648-1b6f1dcf8e03","type":"GlyphRenderer"},{"id":"5b4acaae-f0e5-4976-a0ae-7c5662964327","type":"GlyphRenderer"},{"id":"bf80b6c0-179e-4808-a488-56e0afa9b6ad","type":"GlyphRenderer"},{"id":"728174de-8ea5-4cf6-9a69-6665e53bcb92","type":"GlyphRenderer"},{"id":"34474809-b488-4bd1-b670-cc898beeb54b","type":"GlyphRenderer"},{"id":"557c1710-45bf-4eb3-998c-e46886e12af8","type":"GlyphRenderer"},{"id":"084eb5fd-6cc1-400e-83ec-4a42d19a710e","type":"GlyphRenderer"},{"id":"d2521b24-3831-407b-be1d-4bef65bc2a1c","type":"GlyphRenderer"},{"id":"fef45efe-e464-44ec-a869-5545acd22559","type":"GlyphRenderer"},{"id":"2bd733d0-d025-4388-a394-d72fc2d6729a","type":"GlyphRenderer"},{"id":"41a0c8d9-4a01-47a2-b019-daf2c25acf9d","type":"GlyphRenderer"},{"id":"e0d3ceb6-4c55-4678-9676-33862e4d5bd4","type":"GlyphRenderer"},{"id":"05c26